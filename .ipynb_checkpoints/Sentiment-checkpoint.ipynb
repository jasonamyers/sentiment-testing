# %%
from textblob import TextBlob
from textblob.sentiments import NaiveBayesAnalyzer
import json

# %%
text="""Remember before Twitter when you took a photo of food, got the film developed, then drove around showing everyone the pic? No? Me neither."""

# %%
blob = TextBlob(text)

# %%
for sentence in blob.sentences:
    print(sentence.sentiment)
# Out:
# Sentiment(polarity=0.1, subjectivity=0.3)
# Sentiment(polarity=0.0, subjectivity=0.0)
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
blob = TextBlob(text, analyzer=NaiveBayesAnalyzer())

# %%
for sentence in blob.sentences:
    print(sentence.sentiment)
# Out:
# Sentiment(classification='neg', p_pos=0.4199831739557705, p_neg=0.5800168260442291)
# Sentiment(classification='pos', p_pos=0.5, p_neg=0.5)
# Sentiment(classification='neg', p_pos=0.3717105263157896, p_neg=0.6282894736842106)

# %%
tweet_texts = []

# %%
with open('tweets.txt') as tweets:
    while True:
        line = tweets.readline()
        line = line.strip()
        
        if not line:
            break
            
        try:
            tweet = json.loads(line)
            tweet_text = tweet.get('text')
            if tweet_text:
                tweet_texts.append(tweet_text)
        except Exception as exc_info:
            pass

# %%
for tweet in tweet_texts:
    blob = TextBlob(tweet)
    if blob.detect_language() != 'en':
#         blob = blob.translate()
        continue
    if blob.polarity != 0.0:
        if blob.polarity > 0:
            sentiment = 'pos'
        if blob.polarity < 0:
            sentiment = 'neg'
        print "Pattern Tweet: ", blob, "\nSentiment: ", sentiment, "\n\n"
    else:
        blob = TextBlob(tweet, analyzer=NaiveBayesAnalyzer())
        if blob.detect_language() != 'en':
#         blob = blob.translate()
            continue
        print "Bayes Tweet: ", blob, "\nSentiment: ", blob.sentiment.classification, "\n\n"
# Out:
#  Bayes Tweet:  If his dick has actually been in your mouth ladies he's exempt from your slander
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @saharaguts: @LionCliftonwood is that because of the RPZ?
# Sentiment:  neg
#
#
# Bayes Tweet:  RT @FlirtAndSwipe: Tell your snapchat username with cuties @ https://t.co/cjaxIubWDy https://t.co/ruAgQPSrLS
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @OTreeHill: Season one Nathan Scott 😍  https://t.co/3nSyz8YZ8G
# Sentiment:  pos
#
#
# Bayes Tweet:  https://t.co/UXq7azdsDV
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @KyleDolan_: Christ imagine turning 21 n no even being out yer maws womb yet https://t.co/qWPxRxEDGJ
# Sentiment:  pos
#
#
# Bayes Tweet:  It's in the trash
# Sentiment:  neg
#
#
# Pattern Tweet:  RT @NenoProGuitar: Setting up for #ChinaSuperVocal2016! It's going to be a time :) @karenlizotte I didn't paint my face I swear https://t.c…
# Sentiment:  pos
#
#
# Bayes Tweet:  @null WWF
# Sentiment:  neg
#
#
# Pattern Tweet:  RT @HeartBoxPlus: If you don't like taco bell just because it's not authentic Mexican food I need you to please hush
# Sentiment:  neg
#
#
# Bayes Tweet:  RT @wakkatootti: https://t.co/H14JuCKq8L
# Sentiment:  pos
#
#
# Pattern Tweet:  825RHCH17 - Standalone Financial Results, Limited Review Report for March 31, 2016 https://t.co/iTh6S5glE8
# Sentiment:  neg
#
#
# Bayes Tweet:  https://t.co/w8u4fhorgE
# Sentiment:  pos
#
#
# Pattern Tweet:  Appreciate best and the speediest conveyance with @snapdeal #SnapdealDeliversFastest
# Sentiment:  pos
#
#
# Bayes Tweet:  Government set to evolve practical driving test: https://t.co/pgWW4qezx0 #RSGB https://t.co/8tT30gxkMc
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @eeeiko00: じぇーそん(･∀･) https://t.co/E3uHDxyWVC
# Sentiment:  pos
#
#
# Bayes Tweet:  And/or Twitter https://t.co/Viiu9pyLdz
# Sentiment:  pos
#
#
# Pattern Tweet:  Calling all #Berniecrats #RT and reply to make sure nobody has the #WrongIdea about #Berners #InItToWinIt https://t.co/G8X3Bqapvk
# Sentiment:  pos
#
#
# Pattern Tweet:  Confining a professional relationship to strictly business is ... More for Aquarius https://t.co/ywCWszKQUF
# Sentiment:  pos
#
#
# Pattern Tweet:  1918 $1 FEDERAL RESERVE NOTE - BOSTON -  ** LIGHTLY CIRCULATED ** FREE SHIPPING https://t.co/mCUhvx2o82 https://t.co/v8V8BjwQH2
# Sentiment:  pos
#
#
# Pattern Tweet:  Our 1 year Anniversary info is in the @EveningGazette #Teesside today! Go pick it up ;) https://t.co/CnC4fr2tY6
# Sentiment:  pos
#
#
# Pattern Tweet:  twitters gone dead is everyone snapchatting misha
# Sentiment:  neg
#
#
# Bayes Tweet:  Tengoo friooo lpm jajaj
# Sentiment:  pos
#
#
# Pattern Tweet:  RT @FootyHumour: Deportivo Palencia with the worst Football kit of all time 😭😂 https://t.co/RgFKDEYWv4
# Sentiment:  neg
#
#
# Pattern Tweet:  @estellasrevenge I'm super popular with Toronto t shirt shops
# Sentiment:  pos
#
#
# Pattern Tweet:  RT @TEGmagazine: #Win a large window box in Hampstead Lead Grey from @bayandbox
# Simply follow, like &amp; RT to enter! #FreebieFriday https://…
# Sentiment:  pos
#
#
# Pattern Tweet:  RT @DangerKatt: Honored to be #2 on @Onalytica's Top 100 #VirtualReality Influencers list! https://t.co/BkSVpgl6bw #MORIARTYVR #VR https://…
# Sentiment:  pos
#
#
# Pattern Tweet:  Revered Guru Ji adopts the girls entrapped in prostitution as his own daughters, gets them medically treated #MSGmission
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @__HolaG: 3⃣ https://t.co/YqsCE253fb
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @FemalePains: he had to sneeze https://t.co/G0hdANVEWX
# Sentiment:  neg
#
#
# Bayes Tweet:  RT @Zytronic: Take a look at some FAQ's about our patented Projective Capacitive Technology. https://t.co/DPd5OKEOiv https://t.co/ro2Brb135u
# Sentiment:  neg
#
#
# Bayes Tweet:  RT @PandasReactions: When no one cares for you https://t.co/A3doxhni93
# Sentiment:  neg
#
#
# Pattern Tweet:  You are graced with a natural ability to shine your love light... More for Sagittarius https://t.co/odWwzLMpee
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @FreyaaHowell: My everything's https://t.co/0Uf9LHDasf
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @TrendsHyderabad: #ktucsupersunday is now trending in #Hyderabad https://t.co/mqWZexS7mc
# Sentiment:  pos
#
#
# Pattern Tweet:  RT @Moogfest: Mind melding with the machine mind for artistic ascension. Art &amp; AI at #Moogfest2016 https://t.co/wLO3qZ9MAs https://t.co/tqK…
# Sentiment:  pos
#
#
# Pattern Tweet:  Check out #ACEO #Egrets #Birds Water  #Impressionism Colored Pencil Original Buckman https://t.co/u7Ru96jaDF @eBay
# Sentiment:  pos
#
#
# Bayes Tweet:  10:20
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @AntiSeptic: @djhugu https://t.co/rSxLeeLLEN
# Sentiment:  pos
#
#
# Bayes Tweet:  #NowPlaying on https://t.co/eUWHBeUguL - U Got Me by Noiseshock #hardstyle #rawstyle #nonstop #music #radio https://t.co/8N85UfhvwA
# Sentiment:  neg
#
#
# Bayes Tweet:  https://t.co/BNEwFnPwa5
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @M_G_W_V: ★ＲＥＴＷＥＥＴ
#
# ★ＩＦ
#
# ★ＹＯＵ
#
# ★ＦＯＬＬＯＷＢＡＣＫ
#
# #F4F
# #MGWV
# #FollowTrick
# #FollowPyramid
# #TeamFollowBack
# #AnotherFollowTrain
#
# #ＦＯＬＬＯＷ @Raman_D…
# Sentiment:  pos
#
#
# Pattern Tweet:  RT @WooodAshlynn: It's going to be one damn good summer ✊🏼✊🏼✊🏼
# Sentiment:  pos
#
#
# Pattern Tweet:  RT @raghav_chadha: Powerful speech by Delhi CM Arvind Kejriwal on unholy nexus between BJP and Congress https://t.co/a5L6TrhcuH
# Sentiment:  pos
#
#
# Pattern Tweet:  RT @BrendenUX: God I fucking hate furries #MemeFest https://t.co/AMMcYaR6OS
# Sentiment:  neg
#
#
# Bayes Tweet:  RT @sthronecold: Without A Fight (feat Demi Lovato).mp3 https://t.co/K8HQ7QMsuQ
# Sentiment:  neg
#
#
# Bayes Tweet:  RT @GirlsGeneration: 'SMTOWN'S PET DAY - PART 2 #GirlsGeneration #HYOYEON &amp; #fx #LUNA'. #Vyrl
# https://t.co/UM1YfDn06h
# Sentiment:  pos
#
#
# Bayes Tweet:  @Otr_Beez swear I've never done that.. I've always said thank you and I respect you for telling the truth 😂😭✋🏾.
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @palvinmaniabr: My #TeenChoice nominee for #ChoiceModel is @BarbaraPalvin https://t.co/Eq6yXKJkt5
# Sentiment:  pos
#
#
# Pattern Tweet:  RT @Dri_zzyy: Sometimes no matter how much you want things to happen, all you can do is wait.
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @mahershalalabaz: "@drheatherfurnas: https://t.co/64UnBKptTG"
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @fathmuhhh: @Thnhdpngmpng In Shaa Allah. ☺😂
# Sentiment:  pos
#
#
# Pattern Tweet:  @Destiny041772 @AyamusNiwrehs @Ovidrous15 @RhodaSedana @amor_amy5 @tigress524 hahaha ganoin? Gravy pla sya
# #ALDUBinITALYDay5
# Sentiment:  pos
#
#
# Pattern Tweet:  @MarielleBayani super ganda 💯 hahahahaha feel na feel ko nga Kendall. Crowns up! haha
# Sentiment:  pos
#
#
# Pattern Tweet:  @L0ng_L3gs lol. I know ppl be calling in with off the wall requests
# Sentiment:  pos
#
#
# Bayes Tweet:  It's #FridayThe13th, but don't be a scaredy cat, book an appointment to get your skin checked! #SkinCancerAwareness https://t.co/dae6rudXGD
# Sentiment:  neg
#
#
# Pattern Tweet:  Hala exciting ang episode sa monday
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @blushybieber: Retweet if you want to gain just follow everyone who retweets and follow back whoever follows you🐸
# Sentiment:  pos
#
#
# Pattern Tweet:  I'll show you how much i love you
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @erickjennerr: Snapchat: heyyysexyyy69 https://t.co/lh57EjBdGx
# Sentiment:  pos
#
#
# Pattern Tweet:  Hey - Someone may need this info - Six Best Places to Get Tattooed on #Friday13th in #Denver  https://t.co/859AjbqRYA via @westwordculture
# Sentiment:  pos
#
#
# Pattern Tweet:  RT @ALee_inDC: It's 2016, every body and they fava and uncle coming home or been home. Aint no room in the half way houses. Homelessness we…
# Sentiment:  neg
#
#
# Bayes Tweet:  RT @Raeezus_: 😭😭yelling at me only turn me on soooo
# Sentiment:  pos
#
#
# Pattern Tweet:  RT @peddoc63: 138 members of Reagan admin. investigated, indicted, or convicted of crimes.
# Obama's DOJ is as Corrupt as him! RT✔️ https://t…
# Sentiment:  neg
#
#
# Pattern Tweet:  @Nanny_Lu_Who True 😄
# Now, if it was Friday the 15th that would be a BIG DEAL! 😜
# Sentiment:  pos
#
#
# Bayes Tweet:  アンメルツゴールドDynamite #beatmania https://t.co/kB2x9EjPWA
# Sentiment:  pos
#
#
# Pattern Tweet:  Let's have some fun?.
# Let's have a chat - https://t.co/P9bpSwPRjV  #websites #weekend #winnen
# Sentiment:  pos
#
#
# Bayes Tweet:  4 of 5 stars to Giro di prova by L.A. Witt https://t.co/1XlaZfRVJK
# Sentiment:  neg
#
#
# Pattern Tweet:  RT @Lecerisee: true http://t.co/ioB6SJMHUk
# Sentiment:  pos
#
#
# Bayes Tweet:  @b_t_s__jung かわいい
# Sentiment:  pos
#
#
# Bayes Tweet:  French Louis XV Style Parquetry Inlaid Antique Cabinet Console, 20th Century https://t.co/J8jA4Vfrsy #Antique #Furntiure
# Sentiment:  pos
#
#
# Pattern Tweet:  how to invest large amounts of money wisely,high roi investments. https://t.co/JiOomTiIOP
# Sentiment:  pos
#
#
# Pattern Tweet:  #ReadersFavorite 4-Stars "engaging, witty, and not afraid to poke a little fun" #vampires #IARTG #SNRTG https://t.co/WoAVjImN2U
# Sentiment:  pos
#
#
# Bayes Tweet:  https://t.co/OCzv8H5212
# Sentiment:  pos
#
#
# Bayes Tweet:  Infinite Background WordPress Builder Extension https://t.co/SOTppndVoz #Background #WordPress #Builder
# Sentiment:  pos
#
#
# Pattern Tweet:  @Ladidahdi I kinda think I do too. But I usually eat my reese's cold, so... would that be hard to maneuver?
# Sentiment:  neg
#
#
# Bayes Tweet:  sai @vc_desperado https://t.co/f5G9Ldn6X8
# Sentiment:  pos
#
#
# Bayes Tweet:  ＠timreyo ◝(⑅•ᴗ•⑅)◜ https://t.co/KVrrker62g
# Sentiment:  pos
#
#
# Pattern Tweet:  how to invest large amounts of money wisely,high roi investments. https://t.co/dgRlt73jjV
# Sentiment:  pos
#
#
# Pattern Tweet:  I will do the best I can with this life, to be of use.
# Sentiment:  pos
#
#
# Pattern Tweet:  RT @Lukas_TmUs: Follow everyone who retweets this, 4 mins :D
# Sentiment:  pos
#
#
# Pattern Tweet:  RT @ZeeTVTelugu: We thank Super Star, Mahesh Babu for coming on #KTUCSuperSunday! It was a dream come true for all of us. https://t.co/Ps7J…
# Sentiment:  pos
#
#
# Bayes Tweet:  ballin in the middle of the club no jersey
# Sentiment:  neg
#
#
# Bayes Tweet:  @nabeelak1995 ith August cinemas ne uddeshich allaalo ? 🤔😜😂
# Sentiment:  neg
#
#
# Bayes Tweet:  RT @idndowwn: @1silvr @MozaAlk3bi   https://t.co/r3B7aMc3yM
# Sentiment:  pos
#
#
# Pattern Tweet:  RT @lucyheart_x: Good morning!😉How is my day started...with wearing latex on @DDFNetwork  studio... http://t.co/w1ZkAxxnXw
# Sentiment:  pos
#
#
# Pattern Tweet:  BINGGOY IS BACK 😈 FUCK #DolceAmoreItsAllComingBack
# Sentiment:  neg
#
#
# Bayes Tweet:  RT @wearePhat: https://t.co/91HA1dnrCl
# Sentiment:  pos
#
#
# Pattern Tweet:  I posted a new photo to Facebook https://t.co/P10XM3hNiC
# Sentiment:  pos
#
#
# Pattern Tweet:  Separate crash scenes at Lake Street and Ontario Street near QEW. Avoid both areas #stcath
# Sentiment:  pos
#
#
# Bayes Tweet:  The flow 💯/💯 https://t.co/uT07JQ9gOT
# Sentiment:  pos
#
#
# Bayes Tweet:  EN DIRECTO en #Periscope https://t.co/Wh5P4aVimm
# Sentiment:  neg
#
#
# Bayes Tweet:  Waley https://t.co/102mE8sJR4
# Sentiment:  pos
#
#
# Pattern Tweet:  True https://t.co/XXJDUZCYWm
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @valeriarivasss: OML !  https://t.co/GQqamWqYKJ
# Sentiment:  pos
#
#
# Bayes Tweet:  Doctor's note: minimum daily level of alcohol for W. Churchill in prohibition America
# https://t.co/xUXkDGgJ4a https://t.co/J0cUK4Ulrj
# Sentiment:  neg
#
#
# Pattern Tweet:  Mrs Brown leads focus group - what made good learning at Parkhill Primary this week ? #independentandconfident https://t.co/Cnm34MjbRS
# Sentiment:  pos
#
#
# Pattern Tweet:  A sad farewell to my favorite senior, I love you lots, and I'll miss ya. Until next time. 🔗💓 @ClassicDeb2 https://t.co/vvywqXVVZw
# Sentiment:  pos
#
#
# Pattern Tweet:  Soccer to watch: TV and live streams for Europe’s top leagues, MLS, Mexican playoffs https://t.co/KdvO5vnicY https://t.co/wqM0p9lKQr
# Sentiment:  pos
#
#
# Pattern Tweet:  RT @PaulThomy: Vintage english TV series UFO. Vehicle of the moon base "moon buggy" for to patrol on moon. https://t.co/Lqu8UNevzI
# Sentiment:  neg
#
#
# Bayes Tweet:  RT @wcgirl1: What if #Bernie had gone after Clinton's ‘damn #emails'? https://t.co/7zAyNgUzZz
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @mete_ercan: #VatanİçinBirlikOlalım https://t.co/498I3oVuo0
# Sentiment:  pos
#
#
# Bayes Tweet:  RT @JordLPM: Will Griggs on fire https://t.co/7ZYFAiIUb5
# Sentiment:  pos
#
#
# Pattern Tweet:  @Jakepackun This Defected festival in Croatia looks insane! https://t.co/5gIRPWvwVL
# Sentiment:  neg
#
#
# Pattern Tweet:  Help The World, Grow Your Income: https://t.co/n1o4oFJOsY #entrepreneur #success #startup #charity #smallbiz #coaching
# Sentiment:  pos
#
#
# Bayes Tweet:  Snow Patrol - Engines https://t.co/7K2dsOAFAq #KVGIsports #nowplaying
# Sentiment:  pos
#
#
# Pattern Tweet:  New Cool Christmas Game: 'Can you escape 3D' - iPhone/iPad: https://t.co/DN9PmICrWA , Android: https://t.co/63X6ITCMkW
# Sentiment:  pos
#
#
# Pattern Tweet:  I seriously need a phone with a GOOD camera.
# Sentiment:  pos
#
#
# Pattern Tweet:  RT @F1: .@RHaryantoracing is first out of the blocks this afternoon #FP2 #SpanishGP #F1 https://t.co/7SZbeztPk8
# Sentiment:  pos
#
#
# Bayes Tweet:  https://t.co/jQojBqToXw
# Sentiment:  pos
#
#
# Bayes Tweet:  VR 360 animatie: https://t.co/UyUDl5kwq3 via @YouTube
# Sentiment:  pos
# ---------------------------------------------------------------------------
# URLError                                  Traceback (most recent call last)
# <ipython-input-11-e8bf73233512> in <module>()
#       1 for tweet in tweet_texts:
#       2     blob = TextBlob(tweet)
# ----> 3     if blob.detect_language() != 'en':
#       4 #         blob = blob.translate()
#       5         continue
#
# /Users/jasonmyers/.virtualenvs/sentiment/lib/python2.7/site-packages/textblob/blob.pyc in detect_language(self)
#     524         :rtype: str
#     525         """
# --> 526         return self.translator.detect(self.raw)
#     527
#     528     def correct(self):
#
# /Users/jasonmyers/.virtualenvs/sentiment/lib/python2.7/site-packages/textblob/translate.pyc in detect(self, source, host, type_)
#      70                 "dt": "at", "tk": _calculate_tk(source),
#      71                 "sl": "auto", "text": source}
# ---> 72         response = self._request(self.url, host=host, type_=type_, data=data)
#      73         result, language = json.loads(response)
#      74         return language
#
# /Users/jasonmyers/.virtualenvs/sentiment/lib/python2.7/site-packages/textblob/translate.pyc in _request(self, url, host, type_, data)
#      90         if host or type_:
#      91             req.set_proxy(host=host, type=type_)
# ---> 92         resp = request.urlopen(req)
#      93         content = resp.read()
#      94         return content.decode('utf-8')
#
# /Users/jasonmyers/.pyenv/versions/2.7.11/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     152     else:
#     153         opener = _opener
# --> 154     return opener.open(url, data, timeout)
#     155
#     156 def install_opener(opener):
#
# /Users/jasonmyers/.pyenv/versions/2.7.11/lib/python2.7/urllib2.pyc in open(self, fullurl, data, timeout)
#     429             req = meth(req)
#     430
# --> 431         response = self._open(req, data)
#     432
#     433         # post-process response
#
# /Users/jasonmyers/.pyenv/versions/2.7.11/lib/python2.7/urllib2.pyc in _open(self, req, data)
#     447         protocol = req.get_type()
#     448         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 449                                   '_open', req)
#     450         if result:
#     451             return result
#
# /Users/jasonmyers/.pyenv/versions/2.7.11/lib/python2.7/urllib2.pyc in _call_chain(self, chain, kind, meth_name, *args)
#     407             func = getattr(handler, meth_name)
#     408
# --> 409             result = func(*args)
#     410             if result is not None:
#     411                 return result
#
# /Users/jasonmyers/.pyenv/versions/2.7.11/lib/python2.7/urllib2.pyc in http_open(self, req)
#    1225
#    1226     def http_open(self, req):
# -> 1227         return self.do_open(httplib.HTTPConnection, req)
#    1228
#    1229     http_request = AbstractHTTPHandler.do_request_
#
# /Users/jasonmyers/.pyenv/versions/2.7.11/lib/python2.7/urllib2.pyc in do_open(self, http_class, req, **http_conn_args)
#    1195         except socket.error, err: # XXX what error?
#    1196             h.close()
# -> 1197             raise URLError(err)
#    1198         else:
#    1199             try:
#
# URLError: <urlopen error [Errno 65] No route to host>
